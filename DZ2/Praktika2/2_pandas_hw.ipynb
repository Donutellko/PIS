# %% [markdown]
# ## <center>Практическое задание. Анализ данных пассажиров "Титаника"</center>
#
# **Заполните код в клетках (где написано "Ваш код здесь").**

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# **Считаем данные из файла в память в виде объекта Pandas.DataFrame**

# %%
data = pd.read_csv('titanic_train.csv',
                  index_col='PassengerId')

# %% [markdown]
# **Данные представлены в виде таблицы. Посмотрим на первые 5 строк:**

# %%
data.head(5)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# **Для примера отберем пассажиров, которые сели в Cherbourg (Embarked=C) и заплатили более 200 у.е. за билет (fare > 200).**
#
# Убедитесь, что Вы понимаете, как эта конструкция работает. <br>
# Если нет – посмотрите, как вычисляется выражение в квадратных в скобках.

# %%
data[(data['Embarked'] == 'C') & (data.Fare > 200)].head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 119                 0       1
# 259                 1       1
# 300                 1       1
# 312                 1       1
# 378                 0       1
#
#                                                         Name     Sex   Age  \
# PassengerId
# 119                                 Baxter, Mr. Quigg Edmond    male  24.0
# 259                                         Ward, Miss. Anna  female  35.0
# 300          Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0
# 312                               Ryerson, Miss. Emily Borie  female  18.0
# 378                                Widener, Mr. Harry Elkins    male  27.0
#
#              SibSp  Parch    Ticket      Fare            Cabin Embarked
# PassengerId
# 119              0      1  PC 17558  247.5208          B58 B60        C
# 259              0      0  PC 17755  512.3292              NaN        C
# 300              0      1  PC 17558  247.5208          B58 B60        C
# 312              2      2  PC 17608  262.3750  B57 B59 B63 B66        C
# 378              0      2    113503  211.5000              C82        C

# %% [markdown]
# **Можно отсортировать этих людей по убыванию платы за билет.**

# %%
data[(data['Embarked'] == 'C') & 
     (data['Fare'] > 200)].sort_values(by='Fare',
                               ascending=False).head()
# Out:
#              Survived  Pclass                                   Name     Sex  \
# PassengerId
# 259                 1       1                       Ward, Miss. Anna  female
# 680                 1       1     Cardeza, Mr. Thomas Drake Martinez    male
# 738                 1       1                 Lesurer, Mr. Gustave J    male
# 312                 1       1             Ryerson, Miss. Emily Borie  female
# 743                 1       1  Ryerson, Miss. Susan Parker "Suzette"  female
#
#               Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# PassengerId
# 259          35.0      0      0  PC 17755  512.3292              NaN        C
# 680          36.0      0      1  PC 17755  512.3292      B51 B53 B55        C
# 738          35.0      0      0  PC 17755  512.3292             B101        C
# 312          18.0      2      2  PC 17608  262.3750  B57 B59 B63 B66        C
# 743          21.0      2      2  PC 17608  262.3750  B57 B59 B63 B66        C

# %% [markdown]
# **Пример создания признака.**

# %%
def age_category(age):
    '''
    < 30 -> 1
    >= 30, <55 -> 2
    >= 55 -> 3
    '''
    if age < 30:
        return 1
    elif age < 55:
        return 2
    else:
        return 3

# %%
age_categories = [age_category(age) for age in data.Age]

# %%
data['Age_category'] = age_categories

# %% [markdown]
# **Другой способ – через `apply`.**

# %%
data['Age_category'] = data['Age'].apply(age_category)

# %% [markdown]
# **1. Сколько мужчин / женщин находилось на борту?**
# - 412 мужчин и 479 женщин
# - 314 мужчин и 577 женщин
# - 479 мужчин и 412 женщин
# - 577 мужчин и 314 женщин

# %%
males = data['Sex'][data.Sex == 'male'].count()
females = data['Sex'][data.Sex == 'female'].count()
print(f"{males} мужчин и {females} женщин")
# Out:
# 577 мужчин и 314 женщин

# %% [markdown]
# **2. Выведите распределение переменной `Pclass` (социально-экономический статус) и это же распределение, только для мужчин / женщин по отдельности. Сколько было мужчин 2-го класса?**
# - 104
# - **108**
# - 112
# - 125

# %%
import matplotlib.pyplot as plt

whole = data.Pclass
male = data[data.Sex == 'male'].Pclass
female = data[data.Sex == 'female'].Pclass
plt.pie(whole)
# Out:
# ([<matplotlib.patches.Wedge at 0x1254bc290>,
#   <matplotlib.patches.Wedge at 0x1254bc710>,
#   <matplotlib.patches.Wedge at 0x1254bcbd0>,
#   <matplotlib.patches.Wedge at 0x1254d30d0>,
#   <matplotlib.patches.Wedge at 0x1254d35d0>,
#   <matplotlib.patches.Wedge at 0x1254d3b90>,
#   <matplotlib.patches.Wedge at 0x1254d3fd0>,
#   <matplotlib.patches.Wedge at 0x12542b510>,
#   <matplotlib.patches.Wedge at 0x1254d3590>,
#   <matplotlib.patches.Wedge at 0x1254d3ad0>,
#   <matplotlib.patches.Wedge at 0x125399950>,
#   <matplotlib.patches.Wedge at 0x12543a6d0>,
#   <matplotlib.patches.Wedge at 0x12543ab90>,
#   <matplotlib.patches.Wedge at 0x12543afd0>,
#   <matplotlib.patches.Wedge at 0x125449550>,
#   <matplotlib.patches.Wedge at 0x125449a10>,
#   <matplotlib.patches.Wedge at 0x125449ed0>,
#   <matplotlib.patches.Wedge at 0x1254563d0>,
#   <matplotlib.patches.Wedge at 0x125456890>,
#   <matplotlib.patches.Wedge at 0x125456d50>,
#   <matplotlib.patches.Wedge at 0x1253e4250>,
#   <matplotlib.patches.Wedge at 0x1253e4710>,
#   <matplotlib.patches.Wedge at 0x1253e4bd0>,
#   <matplotlib.patches.Wedge at 0x1253f90d0>,
#   <matplotlib.patches.Wedge at 0x1253f9590>,
#   <matplotlib.patches.Wedge at 0x1253f9a50>,
#   <matplotlib.patches.Wedge at 0x1253f9f10>,
#   <matplotlib.patches.Wedge at 0x125408410>,
#   <matplotlib.patches.Wedge at 0x1254088d0>,
#   <matplotlib.patches.Wedge at 0x125408d90>,
#   <matplotlib.patches.Wedge at 0x125417290>,
#   <matplotlib.patches.Wedge at 0x125417750>,
#   <matplotlib.patches.Wedge at 0x125417c10>,
#   <matplotlib.patches.Wedge at 0x1253a5110>,
#   <matplotlib.patches.Wedge at 0x1253a55d0>,
#   <matplotlib.patches.Wedge at 0x1253a5a90>,
#   <matplotlib.patches.Wedge at 0x1253a5f50>,
#   <matplotlib.patches.Wedge at 0x125409450>,
#   <matplotlib.patches.Wedge at 0x125409910>,
#   <matplotlib.patches.Wedge at 0x125409dd0>,
#   <matplotlib.patches.Wedge at 0x1253c22d0>,
#   <matplotlib.patches.Wedge at 0x1253c2790>,
#   <matplotlib.patches.Wedge at 0x1253c2c50>,
#   <matplotlib.patches.Wedge at 0x1253d1150>,
#   <matplotlib.patches.Wedge at 0x1253d1610>,
#   <matplotlib.patches.Wedge at 0x1253d1ad0>,
#   <matplotlib.patches.Wedge at 0x1253d1f90>,
#   <matplotlib.patches.Wedge at 0x12545f490>,
#   <matplotlib.patches.Wedge at 0x12545f950>,
#   <matplotlib.patches.Wedge at 0x12545fe10>,
#   <matplotlib.patches.Wedge at 0x12546d310>,
#   <matplotlib.patches.Wedge at 0x12546d7d0>,
#   <matplotlib.patches.Wedge at 0x12546dc90>,
#   <matplotlib.patches.Wedge at 0x125478190>,
#   <matplotlib.patches.Wedge at 0x125478650>,
#   <matplotlib.patches.Wedge at 0x125478b10>,
#   <matplotlib.patches.Wedge at 0x125478fd0>,
#   <matplotlib.patches.Wedge at 0x12548b4d0>,
#   <matplotlib.patches.Wedge at 0x12548b990>,
#   <matplotlib.patches.Wedge at 0x12548be50>,
#   <matplotlib.patches.Wedge at 0x125498350>,
#   <matplotlib.patches.Wedge at 0x125498810>,
#   <matplotlib.patches.Wedge at 0x125498cd0>,
#   <matplotlib.patches.Wedge at 0x1254e51d0>,
#   <matplotlib.patches.Wedge at 0x1254e5690>,
#   <matplotlib.patches.Wedge at 0x1254e5b50>,
#   <matplotlib.patches.Wedge at 0x1254e5fd0>,
#   <matplotlib.patches.Wedge at 0x1254f4510>,
#   <matplotlib.patches.Wedge at 0x1254f49d0>,
#   <matplotlib.patches.Wedge at 0x1254f4e90>,
#   <matplotlib.patches.Wedge at 0x125504390>,
#   <matplotlib.patches.Wedge at 0x125504850>,
#   <matplotlib.patches.Wedge at 0x125504d10>,
#   <matplotlib.patches.Wedge at 0x125512210>,
#   <matplotlib.patches.Wedge at 0x1255126d0>,
#   <matplotlib.patches.Wedge at 0x125512b90>,
#   <matplotlib.patches.Wedge at 0x125512fd0>,
#   <matplotlib.patches.Wedge at 0x125520550>,
#   <matplotlib.patches.Wedge at 0x125520a10>,
#   <matplotlib.patches.Wedge at 0x125520ed0>,
#   <matplotlib.patches.Wedge at 0x1255303d0>,
#   <matplotlib.patches.Wedge at 0x125530890>,
#   <matplotlib.patches.Wedge at 0x125530d50>,
#   <matplotlib.patches.Wedge at 0x12553e250>,
#   <matplotlib.patches.Wedge at 0x12553e710>,
#   <matplotlib.patches.Wedge at 0x12553ebd0>,
#   <matplotlib.patches.Wedge at 0x12554c0d0>,
#   <matplotlib.patches.Wedge at 0x12554c590>,
#   <matplotlib.patches.Wedge at 0x12554ca50>,
#   <matplotlib.patches.Wedge at 0x12554cf10>,
#   <matplotlib.patches.Wedge at 0x12555b410>,
#   <matplotlib.patches.Wedge at 0x12555b8d0>,
#   <matplotlib.patches.Wedge at 0x12555bd90>,
#   <matplotlib.patches.Wedge at 0x125568290>,
#   <matplotlib.patches.Wedge at 0x125568750>,
#   <matplotlib.patches.Wedge at 0x125568c10>,
#   <matplotlib.patches.Wedge at 0x125577110>,
#   <matplotlib.patches.Wedge at 0x1255775d0>,
#   <matplotlib.patches.Wedge at 0x125577a90>,
#   <matplotlib.patches.Wedge at 0x125577f50>,
#   <matplotlib.patches.Wedge at 0x125587450>,
#   <matplotlib.patches.Wedge at 0x125587910>,
#   <matplotlib.patches.Wedge at 0x125587dd0>,
#   <matplotlib.patches.Wedge at 0x1255942d0>,
#   <matplotlib.patches.Wedge at 0x125594790>,
#   <matplotlib.patches.Wedge at 0x125594c50>,
#   <matplotlib.patches.Wedge at 0x1255a3150>,
#   <matplotlib.patches.Wedge at 0x1255a3610>,
#   <matplotlib.patches.Wedge at 0x1255a3ad0>,
#   <matplotlib.patches.Wedge at 0x1255a3f90>,
#   <matplotlib.patches.Wedge at 0x1255b4490>,
#   <matplotlib.patches.Wedge at 0x1255b4950>,
#   <matplotlib.patches.Wedge at 0x1255b4e10>,
#   <matplotlib.patches.Wedge at 0x1255c1310>,
#   <matplotlib.patches.Wedge at 0x1255c17d0>,
#   <matplotlib.patches.Wedge at 0x1255c1c90>,
#   <matplotlib.patches.Wedge at 0x1255ce190>,
#   <matplotlib.patches.Wedge at 0x1255ce650>,
#   <matplotlib.patches.Wedge at 0x1255ceb10>,
#   <matplotlib.patches.Wedge at 0x1255cefd0>,
#   <matplotlib.patches.Wedge at 0x1255de4d0>,
#   <matplotlib.patches.Wedge at 0x1255de990>,
#   <matplotlib.patches.Wedge at 0x1255dee50>,
#   <matplotlib.patches.Wedge at 0x1255eb350>,
#   <matplotlib.patches.Wedge at 0x1255eb810>,
#   <matplotlib.patches.Wedge at 0x1255ebcd0>,
#   <matplotlib.patches.Wedge at 0x1255f91d0>,
#   <matplotlib.patches.Wedge at 0x1255f9690>,
#   <matplotlib.patches.Wedge at 0x1255f9b50>,
#   <matplotlib.patches.Wedge at 0x1255f9fd0>,
#   <matplotlib.patches.Wedge at 0x125607510>,
#   <matplotlib.patches.Wedge at 0x1256079d0>,
#   <matplotlib.patches.Wedge at 0x125607e90>,
#   <matplotlib.patches.Wedge at 0x125617390>,
#   <matplotlib.patches.Wedge at 0x125617850>,
#   <matplotlib.patches.Wedge at 0x125617d10>,
#   <matplotlib.patches.Wedge at 0x125625210>,
#   <matplotlib.patches.Wedge at 0x1256256d0>,
#   <matplotlib.patches.Wedge at 0x125625b90>,
#   <matplotlib.patches.Wedge at 0x125625fd0>,
#   <matplotlib.patches.Wedge at 0x125635550>,
#   <matplotlib.patches.Wedge at 0x125635a10>,
#   <matplotlib.patches.Wedge at 0x125635ed0>,
#   <matplotlib.patches.Wedge at 0x1256423d0>,
#   <matplotlib.patches.Wedge at 0x125642890>,
#   <matplotlib.patches.Wedge at 0x125642d50>,
#   <matplotlib.patches.Wedge at 0x125652250>,
#   <matplotlib.patches.Wedge at 0x125652710>,
#   <matplotlib.patches.Wedge at 0x125652bd0>,
#   <matplotlib.patches.Wedge at 0x1256600d0>,
#   <matplotlib.patches.Wedge at 0x125660590>,
#   <matplotlib.patches.Wedge at 0x125660a50>,
#   <matplotlib.patches.Wedge at 0x125660f10>,
#   <matplotlib.patches.Wedge at 0x12566e410>,
#   <matplotlib.patches.Wedge at 0x12566e8d0>,
#   <matplotlib.patches.Wedge at 0x12566ed90>,
#   <matplotlib.patches.Wedge at 0x12567c290>,
#   <matplotlib.patches.Wedge at 0x12567c750>,
#   <matplotlib.patches.Wedge at 0x12567cc10>,
#   <matplotlib.patches.Wedge at 0x12568b110>,
#   <matplotlib.patches.Wedge at 0x12568b5d0>,
#   <matplotlib.patches.Wedge at 0x12568ba90>,
#   <matplotlib.patches.Wedge at 0x12568bf50>,
#   <matplotlib.patches.Wedge at 0x125699450>,
#   <matplotlib.patches.Wedge at 0x125699910>,
#   <matplotlib.patches.Wedge at 0x125699dd0>,
#   <matplotlib.patches.Wedge at 0x1256a92d0>,
#   <matplotlib.patches.Wedge at 0x1256a9790>,
#   <matplotlib.patches.Wedge at 0x1256a9c50>,
#   <matplotlib.patches.Wedge at 0x1256b7150>,
#   <matplotlib.patches.Wedge at 0x1256b7610>,
#   <matplotlib.patches.Wedge at 0x1256b7ad0>,
#   <matplotlib.patches.Wedge at 0x1256b7f90>,
#   <matplotlib.patches.Wedge at 0x1256c6490>,
#   <matplotlib.patches.Wedge at 0x1256c6950>,
#   <matplotlib.patches.Wedge at 0x1256c6e10>,
#   <matplotlib.patches.Wedge at 0x1256d5310>,
#   <matplotlib.patches.Wedge at 0x1256d57d0>,
#   <matplotlib.patches.Wedge at 0x1256d5c90>,
#   <matplotlib.patches.Wedge at 0x1256e0190>,
#   <matplotlib.patches.Wedge at 0x1256e0650>,
#   <matplotlib.patches.Wedge at 0x1256e0b10>,
#   <matplotlib.patches.Wedge at 0x1256e0fd0>,
#   <matplotlib.patches.Wedge at 0x1256f04d0>,
#   <matplotlib.patches.Wedge at 0x1256f0990>,
#   <matplotlib.patches.Wedge at 0x1256f0e50>,
#   <matplotlib.patches.Wedge at 0x1256ff350>,
#   <matplotlib.patches.Wedge at 0x1256ff810>,
#   <matplotlib.patches.Wedge at 0x1256ffcd0>,
#   <matplotlib.patches.Wedge at 0x12570c1d0>,
#   <matplotlib.patches.Wedge at 0x12570c690>,
#   <matplotlib.patches.Wedge at 0x12570cb50>,
#   <matplotlib.patches.Wedge at 0x12570cfd0>,
#   <matplotlib.patches.Wedge at 0x12571a510>,
#   <matplotlib.patches.Wedge at 0x12571a9d0>,
#   <matplotlib.patches.Wedge at 0x12571ae90>,
#   <matplotlib.patches.Wedge at 0x12572b390>,
#   <matplotlib.patches.Wedge at 0x12572b850>,
#   <matplotlib.patches.Wedge at 0x12572bd10>,
#   <matplotlib.patches.Wedge at 0x125739210>,
#   <matplotlib.patches.Wedge at 0x1257396d0>,
#   <matplotlib.patches.Wedge at 0x125739b90>,
#   <matplotlib.patches.Wedge at 0x125739fd0>,
#   <matplotlib.patches.Wedge at 0x125747550>,
#   <matplotlib.patches.Wedge at 0x125747a10>,
#   <matplotlib.patches.Wedge at 0x125747ed0>,
#   <matplotlib.patches.Wedge at 0x1257563d0>,
#   <matplotlib.patches.Wedge at 0x125756890>,
#   <matplotlib.patches.Wedge at 0x125756d50>,
#   <matplotlib.patches.Wedge at 0x125764250>,
#   <matplotlib.patches.Wedge at 0x125764710>,
#   <matplotlib.patches.Wedge at 0x125764bd0>,
#   <matplotlib.patches.Wedge at 0x1257730d0>,
#   <matplotlib.patches.Wedge at 0x125773590>,
#   <matplotlib.patches.Wedge at 0x125773a50>,
#   <matplotlib.patches.Wedge at 0x125773f10>,
#   <matplotlib.patches.Wedge at 0x125781410>,
#   <matplotlib.patches.Wedge at 0x1257818d0>,
#   <matplotlib.patches.Wedge at 0x125781d90>,
#   <matplotlib.patches.Wedge at 0x12578f290>,
#   <matplotlib.patches.Wedge at 0x12578f750>,
#   <matplotlib.patches.Wedge at 0x12578fc10>,
#   <matplotlib.patches.Wedge at 0x12579e110>,
#   <matplotlib.patches.Wedge at 0x12579e5d0>,
#   <matplotlib.patches.Wedge at 0x12579ea90>,
#   <matplotlib.patches.Wedge at 0x12579ef50>,
#   <matplotlib.patches.Wedge at 0x1257ae450>,
#   <matplotlib.patches.Wedge at 0x1257ae910>,
#   <matplotlib.patches.Wedge at 0x1257aedd0>,
#   <matplotlib.patches.Wedge at 0x1257bc2d0>,
#   <matplotlib.patches.Wedge at 0x1257bc790>,
#   <matplotlib.patches.Wedge at 0x1257bcc50>,
#   <matplotlib.patches.Wedge at 0x1257ca150>,
#   <matplotlib.patches.Wedge at 0x1257ca610>,
#   <matplotlib.patches.Wedge at 0x1257caad0>,
#   <matplotlib.patches.Wedge at 0x1257caf90>,
#   <matplotlib.patches.Wedge at 0x1257da490>,
#   <matplotlib.patches.Wedge at 0x1257da950>,
#   <matplotlib.patches.Wedge at 0x1257dae10>,
#   <matplotlib.patches.Wedge at 0x1257e8310>,
#   <matplotlib.patches.Wedge at 0x1257e87d0>,
#   <matplotlib.patches.Wedge at 0x1257e8c90>,
#   <matplotlib.patches.Wedge at 0x1257f5190>,
#   <matplotlib.patches.Wedge at 0x1257f5650>,
#   <matplotlib.patches.Wedge at 0x1257f5b10>,
#   <matplotlib.patches.Wedge at 0x1257f5fd0>,
#   <matplotlib.patches.Wedge at 0x1258044d0>,
#   <matplotlib.patches.Wedge at 0x125804990>,
#   <matplotlib.patches.Wedge at 0x125804e50>,
#   <matplotlib.patches.Wedge at 0x125812350>,
#   <matplotlib.patches.Wedge at 0x125812810>,
#   <matplotlib.patches.Wedge at 0x125812cd0>,
#   <matplotlib.patches.Wedge at 0x1258211d0>,
#   <matplotlib.patches.Wedge at 0x125821690>,
#   <matplotlib.patches.Wedge at 0x125821b50>,
#   <matplotlib.patches.Wedge at 0x125821fd0>,
#   <matplotlib.patches.Wedge at 0x125830510>,
#   <matplotlib.patches.Wedge at 0x1258309d0>,
#   <matplotlib.patches.Wedge at 0x125830e90>,
#   <matplotlib.patches.Wedge at 0x12583e390>,
#   <matplotlib.patches.Wedge at 0x12583e850>,
#   <matplotlib.patches.Wedge at 0x12583ed10>,
#   <matplotlib.patches.Wedge at 0x12584e210>,
#   <matplotlib.patches.Wedge at 0x12584e6d0>,
#   <matplotlib.patches.Wedge at 0x12584eb90>,
#   <matplotlib.patches.Wedge at 0x12584efd0>,
#   <matplotlib.patches.Wedge at 0x12585c550>,
#   <matplotlib.patches.Wedge at 0x12585ca10>,
#   <matplotlib.patches.Wedge at 0x125e62b90>,
#   <matplotlib.patches.Wedge at 0x125ebe150>,
#   <matplotlib.patches.Wedge at 0x126152a10>,
#   <matplotlib.patches.Wedge at 0x125b7e3d0>,
#   <matplotlib.patches.Wedge at 0x10b1b1ad0>,
#   <matplotlib.patches.Wedge at 0x124c73410>,
#   <matplotlib.patches.Wedge at 0x124f29b10>,
#   <matplotlib.patches.Wedge at 0x124ed7ad0>,
#   <matplotlib.patches.Wedge at 0x125080350>,
#   <matplotlib.patches.Wedge at 0x125098590>,
#   <matplotlib.patches.Wedge at 0x125bd5350>,
#   <matplotlib.patches.Wedge at 0x124f6a590>,
#   <matplotlib.patches.Wedge at 0x124f9f350>,
#   <matplotlib.patches.Wedge at 0x124fc8590>,
#   <matplotlib.patches.Wedge at 0x124ffb350>,
#   <matplotlib.patches.Wedge at 0x125024590>,
#   <matplotlib.patches.Wedge at 0x125059350>,
#   <matplotlib.patches.Wedge at 0x1250c0590>,
#   <matplotlib.patches.Wedge at 0x1250f4350>,
#   <matplotlib.patches.Wedge at 0x12511d590>,
#   <matplotlib.patches.Wedge at 0x125151350>,
#   <matplotlib.patches.Wedge at 0x12517a590>,
#   <matplotlib.patches.Wedge at 0x1251ad350>,
#   <matplotlib.patches.Wedge at 0x1251d5590>,
#   <matplotlib.patches.Wedge at 0x12520a350>,
#   <matplotlib.patches.Wedge at 0x125232590>,
#   <matplotlib.patches.Wedge at 0x125266350>,
#   <matplotlib.patches.Wedge at 0x12528e590>,
#   <matplotlib.patches.Wedge at 0x1252c2350>,
#   <matplotlib.patches.Wedge at 0x1252eb590>,
#   <matplotlib.patches.Wedge at 0x125320350>,
#   <matplotlib.patches.Wedge at 0x125347590>,
#   <matplotlib.patches.Wedge at 0x12537b150>,
#   <matplotlib.patches.Wedge at 0x12537b750>,
#   <matplotlib.patches.Wedge at 0x12537bd90>,
#   <matplotlib.patches.Wedge at 0x125fc7dd0>,
#   <matplotlib.patches.Wedge at 0x12538b250>,
#   <matplotlib.patches.Wedge at 0x12538b890>,
#   <matplotlib.patches.Wedge at 0x12538bcd0>,
#   <matplotlib.patches.Wedge at 0x125382050>,
#   <matplotlib.patches.Wedge at 0x125382950>,
#   <matplotlib.patches.Wedge at 0x125382e90>,
#   <matplotlib.patches.Wedge at 0x12538c350>,
#   <matplotlib.patches.Wedge at 0x12538c890>,
#   <matplotlib.patches.Wedge at 0x12538cdd0>,
#   <matplotlib.patches.Wedge at 0x12538d3d0>,
#   <matplotlib.patches.Wedge at 0x12538d810>,
#   <matplotlib.patches.Wedge at 0x12538de50>,
#   <matplotlib.patches.Wedge at 0x12536ea10>,
#   <matplotlib.patches.Wedge at 0x12538e450>,
#   <matplotlib.patches.Wedge at 0x12538ea90>,
#   <matplotlib.patches.Wedge at 0x125e7bd50>,
#   <matplotlib.patches.Wedge at 0x1253e5590>,
#   <matplotlib.patches.Wedge at 0x1253e5ad0>,
#   <matplotlib.patches.Wedge at 0x1253e5fd0>,
#   <matplotlib.patches.Wedge at 0x1254ce650>,
#   <matplotlib.patches.Wedge at 0x1254ceb90>,
#   <matplotlib.patches.Wedge at 0x125391190>,
#   <matplotlib.patches.Wedge at 0x125391650>,
#   <matplotlib.patches.Wedge at 0x125391b90>,
#   <matplotlib.patches.Wedge at 0x125394290>,
#   <matplotlib.patches.Wedge at 0x125394710>,
#   <matplotlib.patches.Wedge at 0x125394c50>,
#   <matplotlib.patches.Wedge at 0x125399310>,
#   <matplotlib.patches.Wedge at 0x125425210>,
#   <matplotlib.patches.Wedge at 0x125425b10>,
#   <matplotlib.patches.Wedge at 0x1253951d0>,
#   <matplotlib.patches.Wedge at 0x124bb0ed0>,
#   <matplotlib.patches.Wedge at 0x12585cd50>,
#   <matplotlib.patches.Wedge at 0x1259752d0>,
#   <matplotlib.patches.Wedge at 0x125975810>,
#   <matplotlib.patches.Wedge at 0x125975d50>,
#   <matplotlib.patches.Wedge at 0x1259832d0>,
#   <matplotlib.patches.Wedge at 0x125983810>,
#   <matplotlib.patches.Wedge at 0x125983d50>,
#   <matplotlib.patches.Wedge at 0x12598f2d0>,
#   <matplotlib.patches.Wedge at 0x12598f810>,
#   <matplotlib.patches.Wedge at 0x12598fd50>,
#   <matplotlib.patches.Wedge at 0x12599c2d0>,
#   <matplotlib.patches.Wedge at 0x12599c810>,
#   <matplotlib.patches.Wedge at 0x12599cd50>,
#   <matplotlib.patches.Wedge at 0x1259a92d0>,
#   <matplotlib.patches.Wedge at 0x1259a9810>,
#   <matplotlib.patches.Wedge at 0x1259a9d50>,
#   <matplotlib.patches.Wedge at 0x1259b72d0>,
#   <matplotlib.patches.Wedge at 0x1259b7810>,
#   <matplotlib.patches.Wedge at 0x1259b7d50>,
#   <matplotlib.patches.Wedge at 0x1259c42d0>,
#   <matplotlib.patches.Wedge at 0x1259c4810>,
#   <matplotlib.patches.Wedge at 0x1259c4d50>,
#   <matplotlib.patches.Wedge at 0x1259d22d0>,
#   <matplotlib.patches.Wedge at 0x1259d2810>,
#   <matplotlib.patches.Wedge at 0x1259d2d50>,
#   <matplotlib.patches.Wedge at 0x1259dd2d0>,
#   <matplotlib.patches.Wedge at 0x1259dd810>,
#   <matplotlib.patches.Wedge at 0x1259ddd50>,
#   <matplotlib.patches.Wedge at 0x1259ec2d0>,
#   <matplotlib.patches.Wedge at 0x1259ec810>,
#   <matplotlib.patches.Wedge at 0x1259ecd50>,
#   <matplotlib.patches.Wedge at 0x1259f92d0>,
#   <matplotlib.patches.Wedge at 0x1259f9810>,
#   <matplotlib.patches.Wedge at 0x1259f9d50>,
#   <matplotlib.patches.Wedge at 0x125a072d0>,
#   <matplotlib.patches.Wedge at 0x125a07810>,
#   <matplotlib.patches.Wedge at 0x125a07d50>,
#   <matplotlib.patches.Wedge at 0x125a132d0>,
#   <matplotlib.patches.Wedge at 0x125a13810>,
#   <matplotlib.patches.Wedge at 0x125a13d50>,
#   <matplotlib.patches.Wedge at 0x125a212d0>,
#   <matplotlib.patches.Wedge at 0x125a21810>,
#   <matplotlib.patches.Wedge at 0x125a21d50>,
#   <matplotlib.patches.Wedge at 0x125a2e2d0>,
#   <matplotlib.patches.Wedge at 0x125a2e810>,
#   <matplotlib.patches.Wedge at 0x125a2ed50>,
#   <matplotlib.patches.Wedge at 0x125a3b2d0>,
#   <matplotlib.patches.Wedge at 0x125a3b810>,
#   <matplotlib.patches.Wedge at 0x125a3bd50>,
#   <matplotlib.patches.Wedge at 0x125a472d0>,
#   <matplotlib.patches.Wedge at 0x125a47810>,
#   <matplotlib.patches.Wedge at 0x125a47d50>,
#   <matplotlib.patches.Wedge at 0x125a552d0>,
#   <matplotlib.patches.Wedge at 0x125a55810>,
#   <matplotlib.patches.Wedge at 0x125a55d50>,
#   <matplotlib.patches.Wedge at 0x125a632d0>,
#   <matplotlib.patches.Wedge at 0x125a63810>,
#   <matplotlib.patches.Wedge at 0x125a63d50>,
#   <matplotlib.patches.Wedge at 0x125a712d0>,
#   <matplotlib.patches.Wedge at 0x125a71810>,
#   <matplotlib.patches.Wedge at 0x125a71d50>,
#   <matplotlib.patches.Wedge at 0x125a7d2d0>,
#   <matplotlib.patches.Wedge at 0x125a7d810>,
#   <matplotlib.patches.Wedge at 0x125a7dd50>,
#   <matplotlib.patches.Wedge at 0x125a8b2d0>,
#   <matplotlib.patches.Wedge at 0x125a8b810>,
#   <matplotlib.patches.Wedge at 0x125a8bd50>,
#   <matplotlib.patches.Wedge at 0x125a962d0>,
#   <matplotlib.patches.Wedge at 0x125a96810>,
#   <matplotlib.patches.Wedge at 0x125a96d50>,
#   <matplotlib.patches.Wedge at 0x125aa52d0>,
#   <matplotlib.patches.Wedge at 0x125aa5810>,
#   <matplotlib.patches.Wedge at 0x125aa5d50>,
#   <matplotlib.patches.Wedge at 0x125ab12d0>,
#   <matplotlib.patches.Wedge at 0x125ab1810>,
#   <matplotlib.patches.Wedge at 0x125ab1d50>,
#   <matplotlib.patches.Wedge at 0x125abf2d0>,
#   <matplotlib.patches.Wedge at 0x125abf810>,
#   <matplotlib.patches.Wedge at 0x125abfd50>,
#   <matplotlib.patches.Wedge at 0x125acb2d0>,
#   <matplotlib.patches.Wedge at 0x125acb810>,
#   <matplotlib.patches.Wedge at 0x125acbd50>,
#   <matplotlib.patches.Wedge at 0x125ada2d0>,
#   <matplotlib.patches.Wedge at 0x125ada810>,
#   <matplotlib.patches.Wedge at 0x125adad50>,
#   <matplotlib.patches.Wedge at 0x125ae82d0>,
#   <matplotlib.patches.Wedge at 0x125ae8810>,
#   <matplotlib.patches.Wedge at 0x125ae8d50>,
#   <matplotlib.patches.Wedge at 0x125af42d0>,
#   <matplotlib.patches.Wedge at 0x125af4810>,
#   <matplotlib.patches.Wedge at 0x125af4d50>,
#   <matplotlib.patches.Wedge at 0x125b002d0>,
#   <matplotlib.patches.Wedge at 0x125b00810>,
#   <matplotlib.patches.Wedge at 0x125b00d50>,
#   <matplotlib.patches.Wedge at 0x125b102d0>,
#   <matplotlib.patches.Wedge at 0x125b10810>,
#   <matplotlib.patches.Wedge at 0x125b10d50>,
#   <matplotlib.patches.Wedge at 0x125b1c2d0>,
#   <matplotlib.patches.Wedge at 0x125b1c810>,
#   <matplotlib.patches.Wedge at 0x125b1cd50>,
#   <matplotlib.patches.Wedge at 0x125be92d0>,
#   <matplotlib.patches.Wedge at 0x125be9810>,
#   <matplotlib.patches.Wedge at 0x125be9d50>,
#   <matplotlib.patches.Wedge at 0x125bf52d0>,
#   <matplotlib.patches.Wedge at 0x125bf5810>,
#   <matplotlib.patches.Wedge at 0x125bf5d50>,
#   <matplotlib.patches.Wedge at 0x125c032d0>,
#   <matplotlib.patches.Wedge at 0x125c03810>,
#   <matplotlib.patches.Wedge at 0x125c03d50>,
#   <matplotlib.patches.Wedge at 0x125c102d0>,
#   <matplotlib.patches.Wedge at 0x125c10810>,
#   <matplotlib.patches.Wedge at 0x125c10d50>,
#   <matplotlib.patches.Wedge at 0x125c1f2d0>,
#   <matplotlib.patches.Wedge at 0x125c1f810>,
#   <matplotlib.patches.Wedge at 0x125c1fd50>,
#   <matplotlib.patches.Wedge at 0x125c2b2d0>,
#   <matplotlib.patches.Wedge at 0x125c2b810>,
#   <matplotlib.patches.Wedge at 0x125c2bd50>,
#   <matplotlib.patches.Wedge at 0x125c382d0>,
#   <matplotlib.patches.Wedge at 0x125c38810>,
#   <matplotlib.patches.Wedge at 0x125c38d50>,
#   <matplotlib.patches.Wedge at 0x125c452d0>,
#   <matplotlib.patches.Wedge at 0x125c45810>,
#   <matplotlib.patches.Wedge at 0x125c45d50>,
#   <matplotlib.patches.Wedge at 0x125c542d0>,
#   <matplotlib.patches.Wedge at 0x125c54810>,
#   <matplotlib.patches.Wedge at 0x125c54d50>,
#   <matplotlib.patches.Wedge at 0x125c602d0>,
#   <matplotlib.patches.Wedge at 0x125c60810>,
#   <matplotlib.patches.Wedge at 0x125c60d50>,
#   <matplotlib.patches.Wedge at 0x125c6c2d0>,
#   <matplotlib.patches.Wedge at 0x125c6c810>,
#   <matplotlib.patches.Wedge at 0x125c6cd50>,
#   <matplotlib.patches.Wedge at 0x125c782d0>,
#   <matplotlib.patches.Wedge at 0x125c78810>,
#   <matplotlib.patches.Wedge at 0x125c78d50>,
#   <matplotlib.patches.Wedge at 0x125c872d0>,
#   <matplotlib.patches.Wedge at 0x125c87810>,
#   <matplotlib.patches.Wedge at 0x125c87d50>,
#   <matplotlib.patches.Wedge at 0x125c952d0>,
#   <matplotlib.patches.Wedge at 0x125c95810>,
#   <matplotlib.patches.Wedge at 0x125c95d50>,
#   <matplotlib.patches.Wedge at 0x125ca32d0>,
#   <matplotlib.patches.Wedge at 0x125ca3810>,
#   <matplotlib.patches.Wedge at 0x125ca3d50>,
#   <matplotlib.patches.Wedge at 0x125caf2d0>,
#   <matplotlib.patches.Wedge at 0x125caf810>,
#   <matplotlib.patches.Wedge at 0x125cafd50>,
#   <matplotlib.patches.Wedge at 0x125cbd2d0>,
#   <matplotlib.patches.Wedge at 0x125cbd810>,
#   <matplotlib.patches.Wedge at 0x125cbdd50>,
#   <matplotlib.patches.Wedge at 0x125cc92d0>,
#   <matplotlib.patches.Wedge at 0x125cc9810>,
#   <matplotlib.patches.Wedge at 0x125cc9d50>,
#   <matplotlib.patches.Wedge at 0x125cd72d0>,
#   <matplotlib.patches.Wedge at 0x125cd7810>,
#   <matplotlib.patches.Wedge at 0x125cd7d50>,
#   <matplotlib.patches.Wedge at 0x125ce32d0>,
#   <matplotlib.patches.Wedge at 0x125ce3810>,
#   <matplotlib.patches.Wedge at 0x125ce3d50>,
#   <matplotlib.patches.Wedge at 0x125cf12d0>,
#   <matplotlib.patches.Wedge at 0x125cf1810>,
#   <matplotlib.patches.Wedge at 0x125cf1d50>,
#   <matplotlib.patches.Wedge at 0x125cfd2d0>,
#   <matplotlib.patches.Wedge at 0x125cfd810>,
#   <matplotlib.patches.Wedge at 0x125cfdd50>,
#   <matplotlib.patches.Wedge at 0x125d0c2d0>,
#   <matplotlib.patches.Wedge at 0x125d0c810>,
#   <matplotlib.patches.Wedge at 0x125d0cd50>,
#   <matplotlib.patches.Wedge at 0x125d192d0>,
#   <matplotlib.patches.Wedge at 0x125d19810>,
#   <matplotlib.patches.Wedge at 0x125d19d50>,
#   <matplotlib.patches.Wedge at 0x125d662d0>,
#   <matplotlib.patches.Wedge at 0x125d66810>,
#   <matplotlib.patches.Wedge at 0x125d66d50>,
#   <matplotlib.patches.Wedge at 0x125d732d0>,
#   <matplotlib.patches.Wedge at 0x125d73810>,
#   <matplotlib.patches.Wedge at 0x125d73d50>,
#   <matplotlib.patches.Wedge at 0x125d812d0>,
#   <matplotlib.patches.Wedge at 0x125d81810>,
#   <matplotlib.patches.Wedge at 0x125d81d50>,
#   <matplotlib.patches.Wedge at 0x125d8d2d0>,
#   <matplotlib.patches.Wedge at 0x125d8d810>,
#   <matplotlib.patches.Wedge at 0x125d8dd50>,
#   <matplotlib.patches.Wedge at 0x125d9b2d0>,
#   <matplotlib.patches.Wedge at 0x125d9b810>,
#   <matplotlib.patches.Wedge at 0x125d9bd50>,
#   <matplotlib.patches.Wedge at 0x125da82d0>,
#   <matplotlib.patches.Wedge at 0x125da8810>,
#   <matplotlib.patches.Wedge at 0x125da8d50>,
#   <matplotlib.patches.Wedge at 0x125db52d0>,
#   <matplotlib.patches.Wedge at 0x125db5810>,
#   <matplotlib.patches.Wedge at 0x125db5d50>,
#   <matplotlib.patches.Wedge at 0x125dc12d0>,
#   <matplotlib.patches.Wedge at 0x125dc1810>,
#   <matplotlib.patches.Wedge at 0x125dc1d50>,
#   <matplotlib.patches.Wedge at 0x125dd02d0>,
#   <matplotlib.patches.Wedge at 0x125dd0810>,
#   <matplotlib.patches.Wedge at 0x125dd0d50>,
#   <matplotlib.patches.Wedge at 0x125ddd2d0>,
#   <matplotlib.patches.Wedge at 0x125ddd810>,
#   <matplotlib.patches.Wedge at 0x125dddd50>,
#   <matplotlib.patches.Wedge at 0x12686b2d0>,
#   <matplotlib.patches.Wedge at 0x12686b810>,
#   <matplotlib.patches.Wedge at 0x12686bd50>,
#   <matplotlib.patches.Wedge at 0x1268772d0>,
#   <matplotlib.patches.Wedge at 0x126877810>,
#   <matplotlib.patches.Wedge at 0x126877d50>,
#   <matplotlib.patches.Wedge at 0x1268852d0>,
#   <matplotlib.patches.Wedge at 0x126885810>,
#   <matplotlib.patches.Wedge at 0x126885d50>,
#   <matplotlib.patches.Wedge at 0x1268912d0>,
#   <matplotlib.patches.Wedge at 0x126891810>,
#   <matplotlib.patches.Wedge at 0x126891d50>,
#   <matplotlib.patches.Wedge at 0x12689f2d0>,
#   <matplotlib.patches.Wedge at 0x12689f810>,
#   <matplotlib.patches.Wedge at 0x12689fd50>,
#   <matplotlib.patches.Wedge at 0x1268ab2d0>,
#   <matplotlib.patches.Wedge at 0x1268ab810>,
#   <matplotlib.patches.Wedge at 0x1268abd50>,
#   <matplotlib.patches.Wedge at 0x1268b92d0>,
#   <matplotlib.patches.Wedge at 0x1268b9810>,
#   <matplotlib.patches.Wedge at 0x1268b9d50>,
#   <matplotlib.patches.Wedge at 0x1268c62d0>,
#   <matplotlib.patches.Wedge at 0x1268c6810>,
#   <matplotlib.patches.Wedge at 0x1268c6d50>,
#   <matplotlib.patches.Wedge at 0x1268d52d0>,
#   <matplotlib.patches.Wedge at 0x1268d5810>,
#   <matplotlib.patches.Wedge at 0x1268d5d50>,
#   <matplotlib.patches.Wedge at 0x1268e12d0>,
#   <matplotlib.patches.Wedge at 0x1268e1810>,
#   <matplotlib.patches.Wedge at 0x1268e1d50>,
#   <matplotlib.patches.Wedge at 0x1268f12d0>,
#   <matplotlib.patches.Wedge at 0x1268f1810>,
#   <matplotlib.patches.Wedge at 0x1268f1d50>,
#   <matplotlib.patches.Wedge at 0x1268fb2d0>,
#   <matplotlib.patches.Wedge at 0x1268fb810>,
#   <matplotlib.patches.Wedge at 0x1268fbd50>,
#   <matplotlib.patches.Wedge at 0x1269092d0>,
#   <matplotlib.patches.Wedge at 0x126909810>,
#   <matplotlib.patches.Wedge at 0x126909d50>,
#   <matplotlib.patches.Wedge at 0x1269152d0>,
#   <matplotlib.patches.Wedge at 0x126915810>,
#   <matplotlib.patches.Wedge at 0x126915d50>,
#   <matplotlib.patches.Wedge at 0x1269232d0>,
#   <matplotlib.patches.Wedge at 0x126923810>,
#   <matplotlib.patches.Wedge at 0x126923d50>,
#   <matplotlib.patches.Wedge at 0x1269302d0>,
#   <matplotlib.patches.Wedge at 0x126930810>,
#   <matplotlib.patches.Wedge at 0x126930d50>,
#   <matplotlib.patches.Wedge at 0x12693d2d0>,
#   <matplotlib.patches.Wedge at 0x12693d810>,
#   <matplotlib.patches.Wedge at 0x12693dd50>,
#   <matplotlib.patches.Wedge at 0x12694b2d0>,
#   <matplotlib.patches.Wedge at 0x12694b810>,
#   <matplotlib.patches.Wedge at 0x12694bd50>,
#   <matplotlib.patches.Wedge at 0x1269582d0>,
#   <matplotlib.patches.Wedge at 0x126958810>,
#   <matplotlib.patches.Wedge at 0x126958d50>,
#   <matplotlib.patches.Wedge at 0x1269642d0>,
#   <matplotlib.patches.Wedge at 0x126964810>,
#   <matplotlib.patches.Wedge at 0x126964d50>,
#   <matplotlib.patches.Wedge at 0x1269732d0>,
#   <matplotlib.patches.Wedge at 0x126973810>,
#   <matplotlib.patches.Wedge at 0x126973d50>,
#   <matplotlib.patches.Wedge at 0x1269802d0>,
#   <matplotlib.patches.Wedge at 0x126980810>,
#   <matplotlib.patches.Wedge at 0x126980d50>,
#   <matplotlib.patches.Wedge at 0x12698d2d0>,
#   <matplotlib.patches.Wedge at 0x12698d810>,
#   <matplotlib.patches.Wedge at 0x12698dd50>,
#   <matplotlib.patches.Wedge at 0x1269992d0>,
#   <matplotlib.patches.Wedge at 0x126999810>,
#   <matplotlib.patches.Wedge at 0x126999d50>,
#   <matplotlib.patches.Wedge at 0x1269a72d0>,
#   <matplotlib.patches.Wedge at 0x1269a7810>,
#   <matplotlib.patches.Wedge at 0x1269a7d50>,
#   <matplotlib.patches.Wedge at 0x1269b42d0>,
#   <matplotlib.patches.Wedge at 0x1269b4810>,
#   <matplotlib.patches.Wedge at 0x1269b4d50>,
#   <matplotlib.patches.Wedge at 0x1269c22d0>,
#   <matplotlib.patches.Wedge at 0x1269c2810>,
#   <matplotlib.patches.Wedge at 0x1269c2d50>,
#   <matplotlib.patches.Wedge at 0x1269ce2d0>,
#   <matplotlib.patches.Wedge at 0x1269ce810>,
#   <matplotlib.patches.Wedge at 0x1269ced50>,
#   <matplotlib.patches.Wedge at 0x1269dc2d0>,
#   <matplotlib.patches.Wedge at 0x1269dc810>,
#   <matplotlib.patches.Wedge at 0x1269dcd50>,
#   <matplotlib.patches.Wedge at 0x1269e92d0>,
#   <matplotlib.patches.Wedge at 0x1269e9810>,
#   <matplotlib.patches.Wedge at 0x1269e9d50>,
#   <matplotlib.patches.Wedge at 0x1269f82d0>,
#   <matplotlib.patches.Wedge at 0x1269f8810>,
#   <matplotlib.patches.Wedge at 0x1269f8d50>,
#   <matplotlib.patches.Wedge at 0x126a042d0>,
#   <matplotlib.patches.Wedge at 0x126a04810>,
#   <matplotlib.patches.Wedge at 0x126a04d50>,
#   <matplotlib.patches.Wedge at 0x126a102d0>,
#   <matplotlib.patches.Wedge at 0x126a10810>,
#   <matplotlib.patches.Wedge at 0x126a10d50>,
#   <matplotlib.patches.Wedge at 0x126a1c2d0>,
#   <matplotlib.patches.Wedge at 0x126a1c810>,
#   <matplotlib.patches.Wedge at 0x126a1cd50>,
#   <matplotlib.patches.Wedge at 0x126a2c2d0>,
#   <matplotlib.patches.Wedge at 0x126a2c810>,
#   <matplotlib.patches.Wedge at 0x126a2cd50>,
#   <matplotlib.patches.Wedge at 0x126a392d0>,
#   <matplotlib.patches.Wedge at 0x126a39810>,
#   <matplotlib.patches.Wedge at 0x126a39d50>,
#   <matplotlib.patches.Wedge at 0x126a462d0>,
#   <matplotlib.patches.Wedge at 0x126a46810>,
#   <matplotlib.patches.Wedge at 0x126a46d50>,
#   <matplotlib.patches.Wedge at 0x126a522d0>,
#   <matplotlib.patches.Wedge at 0x126a52810>,
#   <matplotlib.patches.Wedge at 0x126a52d50>,
#   <matplotlib.patches.Wedge at 0x126a622d0>,
#   <matplotlib.patches.Wedge at 0x126a62810>,
#   <matplotlib.patches.Wedge at 0x126a62d50>,
#   <matplotlib.patches.Wedge at 0x126a6d2d0>,
#   <matplotlib.patches.Wedge at 0x126a6d810>,
#   <matplotlib.patches.Wedge at 0x126a6dd50>,
#   <matplotlib.patches.Wedge at 0x126a7b2d0>,
#   <matplotlib.patches.Wedge at 0x126a7b810>,
#   <matplotlib.patches.Wedge at 0x126a7bd50>,
#   <matplotlib.patches.Wedge at 0x126a872d0>,
#   <matplotlib.patches.Wedge at 0x126a87810>,
#   <matplotlib.patches.Wedge at 0x126a87d50>,
#   <matplotlib.patches.Wedge at 0x126a942d0>,
#   <matplotlib.patches.Wedge at 0x126a94810>,
#   <matplotlib.patches.Wedge at 0x126a94d50>,
#   <matplotlib.patches.Wedge at 0x126aa22d0>,
#   <matplotlib.patches.Wedge at 0x126aa2810>,
#   <matplotlib.patches.Wedge at 0x126aa2d50>,
#   <matplotlib.patches.Wedge at 0x126ab02d0>,
#   <matplotlib.patches.Wedge at 0x126ab0810>,
#   <matplotlib.patches.Wedge at 0x126ab0d50>,
#   <matplotlib.patches.Wedge at 0x126abd2d0>,
#   <matplotlib.patches.Wedge at 0x126abd810>,
#   <matplotlib.patches.Wedge at 0x126abdd50>,
#   <matplotlib.patches.Wedge at 0x126ac92d0>,
#   <matplotlib.patches.Wedge at 0x126ac9810>,
#   <matplotlib.patches.Wedge at 0x126ac9d50>,
#   <matplotlib.patches.Wedge at 0x126ad62d0>,
#   <matplotlib.patches.Wedge at 0x126ad6810>,
#   <matplotlib.patches.Wedge at 0x126ad6d50>,
#   <matplotlib.patches.Wedge at 0x126ae52d0>,
#   <matplotlib.patches.Wedge at 0x126ae5810>,
#   <matplotlib.patches.Wedge at 0x126ae5d50>,
#   <matplotlib.patches.Wedge at 0x126af12d0>,
#   <matplotlib.patches.Wedge at 0x126af1810>,
#   <matplotlib.patches.Wedge at 0x126af1d50>,
#   <matplotlib.patches.Wedge at 0x126aff2d0>,
#   <matplotlib.patches.Wedge at 0x126aff810>,
#   <matplotlib.patches.Wedge at 0x126affd50>,
#   <matplotlib.patches.Wedge at 0x126b0c2d0>,
#   <matplotlib.patches.Wedge at 0x126b0c810>,
#   <matplotlib.patches.Wedge at 0x126b0cd50>,
#   <matplotlib.patches.Wedge at 0x126b1a2d0>,
#   <matplotlib.patches.Wedge at 0x126b1a810>,
#   <matplotlib.patches.Wedge at 0x126b1ad50>,
#   <matplotlib.patches.Wedge at 0x126b252d0>,
#   <matplotlib.patches.Wedge at 0x126b25810>,
#   <matplotlib.patches.Wedge at 0x126b25d50>,
#   <matplotlib.patches.Wedge at 0x126b342d0>,
#   <matplotlib.patches.Wedge at 0x126b34810>,
#   <matplotlib.patches.Wedge at 0x126b34d50>,
#   <matplotlib.patches.Wedge at 0x126b402d0>,
#   <matplotlib.patches.Wedge at 0x126b40810>,
#   <matplotlib.patches.Wedge at 0x126b40d50>,
#   <matplotlib.patches.Wedge at 0x126b502d0>,
#   <matplotlib.patches.Wedge at 0x126b50810>,
#   <matplotlib.patches.Wedge at 0x126b50d50>,
#   <matplotlib.patches.Wedge at 0x126b5b2d0>,
#   <matplotlib.patches.Wedge at 0x126b5b810>,
#   <matplotlib.patches.Wedge at 0x126b5bd50>,
#   <matplotlib.patches.Wedge at 0x126b692d0>,
#   <matplotlib.patches.Wedge at 0x126b69810>,
#   <matplotlib.patches.Wedge at 0x126b69d50>,
#   <matplotlib.patches.Wedge at 0x126b752d0>,
#   <matplotlib.patches.Wedge at 0x126b75810>,
#   <matplotlib.patches.Wedge at 0x126b75d50>,
#   <matplotlib.patches.Wedge at 0x126b832d0>,
#   <matplotlib.patches.Wedge at 0x126b83810>,
#   <matplotlib.patches.Wedge at 0x126b83d50>,
#   <matplotlib.patches.Wedge at 0x126b902d0>,
#   <matplotlib.patches.Wedge at 0x126b90810>,
#   <matplotlib.patches.Wedge at 0x126b90d50>,
#   <matplotlib.patches.Wedge at 0x126b9d2d0>,
#   <matplotlib.patches.Wedge at 0x126b9d810>,
#   <matplotlib.patches.Wedge at 0x126b9dd50>,
#   <matplotlib.patches.Wedge at 0x126baa2d0>,
#   <matplotlib.patches.Wedge at 0x126baa810>,
#   <matplotlib.patches.Wedge at 0x126baad50>,
#   <matplotlib.patches.Wedge at 0x126bb92d0>,
#   <matplotlib.patches.Wedge at 0x126bb9810>,
#   <matplotlib.patches.Wedge at 0x126bb9d50>,
#   <matplotlib.patches.Wedge at 0x126bc52d0>,
#   <matplotlib.patches.Wedge at 0x126bc5810>,
#   <matplotlib.patches.Wedge at 0x126bc5d50>,
#   <matplotlib.patches.Wedge at 0x126bd32d0>,
#   <matplotlib.patches.Wedge at 0x126bd3810>,
#   <matplotlib.patches.Wedge at 0x126bd3d50>,
#   <matplotlib.patches.Wedge at 0x126bde2d0>,
#   <matplotlib.patches.Wedge at 0x126bde810>,
#   <matplotlib.patches.Wedge at 0x126bded50>,
#   <matplotlib.patches.Wedge at 0x126bec2d0>,
#   <matplotlib.patches.Wedge at 0x126bec810>,
#   <matplotlib.patches.Wedge at 0x126becd50>,
#   <matplotlib.patches.Wedge at 0x126bf92d0>,
#   <matplotlib.patches.Wedge at 0x126bf9810>,
#   <matplotlib.patches.Wedge at 0x126bf9d50>,
#   <matplotlib.patches.Wedge at 0x126c082d0>,
#   <matplotlib.patches.Wedge at 0x126c08810>,
#   <matplotlib.patches.Wedge at 0x126c08d50>,
#   <matplotlib.patches.Wedge at 0x126c142d0>,
#   <matplotlib.patches.Wedge at 0x126c14810>,
#   <matplotlib.patches.Wedge at 0x126c14d50>,
#   <matplotlib.patches.Wedge at 0x126c212d0>,
#   <matplotlib.patches.Wedge at 0x126c21810>,
#   <matplotlib.patches.Wedge at 0x126c21d50>,
#   <matplotlib.patches.Wedge at 0x126c2f2d0>,
#   <matplotlib.patches.Wedge at 0x126c2f810>,
#   <matplotlib.patches.Wedge at 0x126c2fd50>,
#   <matplotlib.patches.Wedge at 0x126c3c2d0>,
#   <matplotlib.patches.Wedge at 0x126c3c810>,
#   <matplotlib.patches.Wedge at 0x126c3cd50>,
#   <matplotlib.patches.Wedge at 0x126c492d0>,
#   <matplotlib.patches.Wedge at 0x126c49810>,
#   <matplotlib.patches.Wedge at 0x126c49d50>,
#   <matplotlib.patches.Wedge at 0x126c562d0>,
#   <matplotlib.patches.Wedge at 0x126c56810>,
#   <matplotlib.patches.Wedge at 0x126c56d50>,
#   <matplotlib.patches.Wedge at 0x126c632d0>,
#   <matplotlib.patches.Wedge at 0x126c63810>,
#   <matplotlib.patches.Wedge at 0x126c63d50>,
#   <matplotlib.patches.Wedge at 0x126c712d0>,
#   <matplotlib.patches.Wedge at 0x126c71810>,
#   <matplotlib.patches.Wedge at 0x126c71d50>,
#   <matplotlib.patches.Wedge at 0x126c7d2d0>,
#   <matplotlib.patches.Wedge at 0x126c7d810>,
#   <matplotlib.patches.Wedge at 0x126c7dd50>,
#   <matplotlib.patches.Wedge at 0x126c8c2d0>,
#   <matplotlib.patches.Wedge at 0x126c8c810>,
#   <matplotlib.patches.Wedge at 0x126c8cd50>,
#   <matplotlib.patches.Wedge at 0x126c972d0>,
#   <matplotlib.patches.Wedge at 0x126c97810>,
#   <matplotlib.patches.Wedge at 0x126c97d50>,
#   <matplotlib.patches.Wedge at 0x126ca62d0>,
#   <matplotlib.patches.Wedge at 0x126ca6810>,
#   <matplotlib.patches.Wedge at 0x126ca6d50>,
#   <matplotlib.patches.Wedge at 0x126cb22d0>,
#   <matplotlib.patches.Wedge at 0x126cb2810>,
#   <matplotlib.patches.Wedge at 0x126cb2d50>,
#   <matplotlib.patches.Wedge at 0x126cc12d0>,
#   <matplotlib.patches.Wedge at 0x126cc1810>,
#   <matplotlib.patches.Wedge at 0x126cc1d50>,
#   <matplotlib.patches.Wedge at 0x126ccd2d0>,
#   <matplotlib.patches.Wedge at 0x126ccd810>,
#   <matplotlib.patches.Wedge at 0x126ccdd50>,
#   <matplotlib.patches.Wedge at 0x126cdb2d0>,
#   <matplotlib.patches.Wedge at 0x126cdb810>,
#   <matplotlib.patches.Wedge at 0x126cdbd50>,
#   <matplotlib.patches.Wedge at 0x126ce72d0>,
#   <matplotlib.patches.Wedge at 0x126ce7810>,
#   <matplotlib.patches.Wedge at 0x126ce7d50>,
#   <matplotlib.patches.Wedge at 0x126cf42d0>,
#   <matplotlib.patches.Wedge at 0x126cf4810>,
#   <matplotlib.patches.Wedge at 0x126cf4d50>,
#   <matplotlib.patches.Wedge at 0x126d012d0>,
#   <matplotlib.patches.Wedge at 0x126d01810>,
#   <matplotlib.patches.Wedge at 0x126d01d50>,
#   <matplotlib.patches.Wedge at 0x126d102d0>,
#   <matplotlib.patches.Wedge at 0x126d10810>,
#   <matplotlib.patches.Wedge at 0x126d10d50>,
#   <matplotlib.patches.Wedge at 0x126d1d2d0>,
#   <matplotlib.patches.Wedge at 0x126d1d810>,
#   <matplotlib.patches.Wedge at 0x126d1dd50>,
#   <matplotlib.patches.Wedge at 0x126d2a2d0>,
#   <matplotlib.patches.Wedge at 0x126d2a810>,
#   <matplotlib.patches.Wedge at 0x126d2ad50>,
#   <matplotlib.patches.Wedge at 0x126d362d0>,
#   <matplotlib.patches.Wedge at 0x126d36810>,
#   <matplotlib.patches.Wedge at 0x126d36d50>,
#   <matplotlib.patches.Wedge at 0x126d452d0>,
#   <matplotlib.patches.Wedge at 0x126d45810>,
#   <matplotlib.patches.Wedge at 0x126d45d50>,
#   <matplotlib.patches.Wedge at 0x126d512d0>,
#   <matplotlib.patches.Wedge at 0x126d51810>,
#   <matplotlib.patches.Wedge at 0x126d51d50>,
#   <matplotlib.patches.Wedge at 0x126d5e2d0>,
#   <matplotlib.patches.Wedge at 0x126d5e810>,
#   <matplotlib.patches.Wedge at 0x126d5ed50>,
#   <matplotlib.patches.Wedge at 0x126d6a2d0>,
#   <matplotlib.patches.Wedge at 0x126d6a810>,
#   <matplotlib.patches.Wedge at 0x126d6ad50>,
#   <matplotlib.patches.Wedge at 0x126d792d0>,
#   <matplotlib.patches.Wedge at 0x126d79810>,
#   <matplotlib.patches.Wedge at 0x126d79d50>,
#   <matplotlib.patches.Wedge at 0x126d862d0>,
#   <matplotlib.patches.Wedge at 0x126d86810>,
#   <matplotlib.patches.Wedge at 0x126d86d50>,
#   <matplotlib.patches.Wedge at 0x126d932d0>,
#   <matplotlib.patches.Wedge at 0x126d93810>,
#   <matplotlib.patches.Wedge at 0x126d93d50>,
#   <matplotlib.patches.Wedge at 0x126da12d0>,
#   <matplotlib.patches.Wedge at 0x126da1810>,
#   <matplotlib.patches.Wedge at 0x126da1d50>,
#   <matplotlib.patches.Wedge at 0x126daf2d0>,
#   <matplotlib.patches.Wedge at 0x126daf810>,
#   <matplotlib.patches.Wedge at 0x126dafd50>,
#   <matplotlib.patches.Wedge at 0x126dbb2d0>,
#   <matplotlib.patches.Wedge at 0x126dbb810>,
#   <matplotlib.patches.Wedge at 0x126dbbd50>,
#   <matplotlib.patches.Wedge at 0x126dc92d0>,
#   <matplotlib.patches.Wedge at 0x126dc9810>,
#   <matplotlib.patches.Wedge at 0x126dc9d50>,
#   <matplotlib.patches.Wedge at 0x126dd52d0>,
#   <matplotlib.patches.Wedge at 0x126dd5810>,
#   <matplotlib.patches.Wedge at 0x126dd5d50>,
#   <matplotlib.patches.Wedge at 0x126de22d0>,
#   <matplotlib.patches.Wedge at 0x126de2810>,
#   <matplotlib.patches.Wedge at 0x126de2d50>,
#   <matplotlib.patches.Wedge at 0x126def2d0>,
#   <matplotlib.patches.Wedge at 0x126def810>,
#   <matplotlib.patches.Wedge at 0x126defd50>,
#   <matplotlib.patches.Wedge at 0x126dfe2d0>,
#   <matplotlib.patches.Wedge at 0x126dfe810>,
#   <matplotlib.patches.Wedge at 0x126dfed50>,
#   <matplotlib.patches.Wedge at 0x126e092d0>,
#   <matplotlib.patches.Wedge at 0x126e09810>,
#   <matplotlib.patches.Wedge at 0x126e09d50>,
#   <matplotlib.patches.Wedge at 0x126e182d0>,
#   <matplotlib.patches.Wedge at 0x126e18810>,
#   <matplotlib.patches.Wedge at 0x126e18d50>,
#   <matplotlib.patches.Wedge at 0x126e242d0>,
#   <matplotlib.patches.Wedge at 0x126e24810>,
#   <matplotlib.patches.Wedge at 0x126e24d50>,
#   <matplotlib.patches.Wedge at 0x126e332d0>,
#   <matplotlib.patches.Wedge at 0x126e33810>,
#   <matplotlib.patches.Wedge at 0x126e33d50>,
#   <matplotlib.patches.Wedge at 0x126e3f2d0>,
#   <matplotlib.patches.Wedge at 0x126e3f810>,
#   <matplotlib.patches.Wedge at 0x126e3fd50>,
#   <matplotlib.patches.Wedge at 0x126e4d2d0>,
#   <matplotlib.patches.Wedge at 0x126e4d810>,
#   <matplotlib.patches.Wedge at 0x126e4dd50>,
#   <matplotlib.patches.Wedge at 0x126e592d0>,
#   <matplotlib.patches.Wedge at 0x126e59810>,
#   <matplotlib.patches.Wedge at 0x126e59d50>,
#   <matplotlib.patches.Wedge at 0x126e662d0>,
#   <matplotlib.patches.Wedge at 0x126e66810>,
#   <matplotlib.patches.Wedge at 0x126e66d50>,
#   <matplotlib.patches.Wedge at 0x126e732d0>,
#   <matplotlib.patches.Wedge at 0x126e73810>],
#  [Text(1.0999884538922642, 0.0050399706057135795, ''),
#   Text(1.0999371383462864, 0.01175974857651262, ''),
#   Text(1.099844772374293, 0.018479087665240975, ''),
#   Text(1.0997113594234473, 0.025197737101447754, ''),
#   Text(1.099536904472814, 0.031915446140420384, ''),
#   Text(1.099198282960286, 0.041989697988427804, ''),
#   Text(1.0989212548451757, 0.04870395927955533, ''),
#   Text(1.0986032142175353, 0.055416402904738725, ''),
#   Text(1.0980492812010243, 0.06548111219209753, ''),
#   Text(1.0975172340939845, 0.07386420558491438, ''),
#   Text(1.0969211869211954, 0.08224299169774775, ''),
#   Text(1.0963982923690079, 0.088942590980495, ''),
#   Text(1.0958344794630206, 0.09563887086332079, ''),
#   Text(1.0949120846420126, 0.10567652012099091, ''),
#   Text(1.0938977486825128, 0.11570529558896771, ''),
#   Text(1.0929822971122578, 0.12405522237782741, ''),
#   Text(1.092003109924279, 0.13239791507309656, ''),
#   Text(1.0909602442184037, 0.14073288718320634, ''),
#   Text(1.0898537608077759, 0.14905965266680224, ''),
#   Text(1.088442096465593, 0.1590402547834502, ''),
#   Text(1.0871958864435591, 0.16734725722342703, ''),
#   Text(1.086153268102587, 0.17398585629317723, ''),
#   Text(1.0847929961420695, 0.1822749448528579, ''),
#   Text(1.0836592288345683, 0.18889858591759992, ''),
#   Text(1.0824850186040598, 0.19551517715453332, ''),
#   Text(1.0806479690607536, 0.20542630543547424, ''),
#   Text(1.0787201761545981, 0.21532018381236995, ''),
#   Text(1.0773846475248745, 0.2219061091491228, ''),
#   Text(1.0760089101439214, 0.22848375279413305, ''),
#   Text(1.0738700253985611, 0.2383341531348244, ''),
#   Text(1.0723939940454548, 0.2448900192642342, ''),
#   Text(1.0716409664200761, 0.24816454035628388, ''),
#   Text(1.0701049224461634, 0.2547066056396865, ''),
#   Text(1.0681287128324706, 0.2628707911177086, ''),
#   Text(1.0669130820902355, 0.2677619750164585, ''),
#   Text(1.0660902168756365, 0.27101964777864085, ''),
#   Text(1.0644146537452541, 0.2775273768340179, ''),
#   Text(1.0618268451937156, 0.2872694742327515, ''),
#   Text(1.0591498737126614, 0.2969874492540947, ''),
#   Text(1.0563839640907386, 0.3066804858675189, ''),
#   Text(1.0535293485848405, 0.3163477701366047, ''),
#   Text(1.0510829135833337, 0.32438358277380586, ''),
#   Text(1.0485751862635952, 0.33240047947057294, ''),
#   Text(1.0460063128599695, 0.3403979927336407, ''),
#   Text(1.043376443172443, 0.34837565620005917, ''),
#   Text(1.0917996381790909, -0.13406546934989091, ''),
#   Text(1.0927915651971118, -0.12572428179968442, ''),
#   Text(1.0938977564476509, -0.11570522217599422, ''),
#   Text(1.094912091734106, -0.10567644663994397, ''),
#   Text(1.0958344858814735, -0.09563879732037067, ''),
#   Text(1.0963982983380642, -0.08894251739970686, ''),
#   Text(1.096794306109754, -0.0839181153579096, ''),
#   Text(1.0974031486813103, -0.0755402493002634, ''),
#   Text(1.0980492855955488, -0.06548103850050943, ''),
#   Text(1.0985173010484564, -0.0570941266437746, ''),
#   Text(1.0989212581182155, -0.04870388542897086, ''),
#   Text(1.099321416629348, -0.038631890195066285, ''),
#   Text(1.0995843676007093, -0.030236046834006013, ''),
#   Text(1.0997113611191072, -0.025197663097216993, ''),
#   Text(1.0998447736178265, -0.018479013652032524, ''),
#   Text(1.0999371391376471, -0.0117596745570887, ''),
#   Text(1.0999884542314227, -0.005039896582835674, '')])

# %% [markdown]
# **3. Каковы медиана и стандартное отклонение платежей (`Fare`)? Округлите до 2 десятичных знаков.**
# - **Медиана – 14.45, стандартное отклонение – 49.69**
# - Медиана – 15.1, стандартное отклонение – 12.15
# - Медиана – 13.15, стандартное отклонение – 35.3
# - Медиана – 17.43, стандартное отклонение – 39.1

# %%
description = data.Fare.describe()
median = np.round(description['50%'], 2)
std = np.round(description['std'], 2)
print(f"Медиана - {median}, стандартное отклонение – {std}")
# Out:
# Медиана - 14.45, стандартное отклонение – 49.69

# %% [markdown]
# **4. Правда ли, что люди моложе 30 лет выживали чаще, чем люди старше 60 лет? Каковы доли выживших в обеих группах?**
# - 22.7% среди молодых и 40.6% среди старых
# - **40.6% среди молодых и 22.7% среди старых**
# - 35.3% среди молодых и 27.4% среди старых
# - 27.4% среди молодых и 35.3% среди старых

# %%
young = data[data['Age'] < 30]['Survived']
old = data[data['Age'] > 60]['Survived']

res_young = np.round(np.average(young) * 100, 1)
res_old = np.round(np.average(old) * 100, 1)
print(f"{res_young}% среди молодых и {res_old}% среди старых")
# Out:
# 40.6% среди молодых и 22.7% среди старых

# %% [markdown]
# **5. Правда ли, что женщины выживали чаще мужчин? Каковы доли выживших в обеих группах?**
# - 30.2% среди мужчин и 46.2% среди женщин
# - 35.7% среди мужчин и 74.2% среди женщин
# - 21.1% среди мужчин и 46.2% среди женщин
# - 18.9% среди мужчин и 74.2% среди женщин

# %% [markdown]
# **6. Найдите самое популярное имя среди пассажиров Титаника мужского пола?**
# - Charles
# - Thomas
# - William
# - John

# %%
# Ваш код здесь

# %% [markdown]
# **7. Сравните графически распределение стоимости билетов и возраста у спасенных и у погибших. Средний возраст погибших выше, верно?**
# - Да
# - Нет

# %%
# Ваш код здесь

# %% [markdown]
# **8. Как отличается средний возраст мужчин / женщин в зависимости от класса обслуживания? Выберите верные утверждения:**
# - В среднем мужчины 1-го класса старше 40 лет
# - В среднем женщины 1-го класса старше 40 лет
# - Мужчины всех классов в среднем старше женщин того же класса
# - В среднем люди в 1 классе старше, чем во 2-ом, а те старше представителей 3-го класса

# %%
# Ваш код здесь
